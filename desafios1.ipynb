# %% [markdown]
# - ***Desafio 1 Condicionais***
#
# ***Crie um sistema de e-commerce, onde o usuário possa:***
#
# *Utilize variáveis, listas, condicionais*
#
# Foco resolver o problema
#
# Vamos trabalhar:
#
# ***Criatividade | Pensamento lógico | Flexibilidade cognitiva***
#
# -cadastrar-se
# -comprar um produto
# -descobrir o valor total
# -pagar

# %%
lista_cadastro = []
produtos = ["Vestido", "Tênis", "Blusa", "Boné"]
valores = [50.0, 100.0, 50.0, 55.0]
carrinho = []
lista_valor = []
forma_de_pagar = ["Pix", "Cartão de crédito", "Cartão de débito" ]

print("Girls Moda")
print("Seja Bem-vindo")

# Cadastro
nome = input("Digite seu nome: ")
e_mail = input("Digite seu e-mail: ")
senha = input("Digite sua senha: ")

print(nome)
print(e_mail)
print(senha)

lista_cadastro.append({
    "nome": nome,
    "e_mail": e_mail,
    "senha": senha
    })

print('''
      ''')

print("cadastro do cliente")


for pessoa in lista_cadastro: 
    print(f'''
    nome: {pessoa["nome"]},
    e_mail: {pessoa["e_mail"]},
    senha: {pessoa["senha"]}
          ''')
    
print ('''
       ''')

produto1 = int(input(f"Digite o código do produto: 0 - Vestido, 1 - Tênis, 2 - Blusa, 3 - Boné"))
produto2 = int(input(f"Digite o código do produto: 0 - Vestido, 1 - Tênis, 2 - Blusa, 3 - Boné"))

carrinho = [produtos[produto1], produtos[produto2]]
lista_valor = [valores[produto1], valores[produto2]]



print(produto1)
print(produto2)
print(carrinho)
print(lista_valor)

soma = sum(lista_valor)
print(f"Valor a pagar: R${soma}")

forma_pagamento = int(input(f"Digite a forma de pagamento: 0 - Pix, 1 - Cartão de crédito, 2 - Cartão de débito"))
print(forma_pagamento)

if forma_pagamento == 0:
    print("Pix ficaria a vista")
elif forma_pagamento == 1:
    print("Para pagamento de cartão de crédito, você pode parcela em 12x sem juros ")
else:
    print("Para forma de pagamento de cartão de débito, você não pode parcela ")
# Out:
# Girls Moda
# Seja Bem-vindo
# eddd
# ssd
# 23334
#
#
# cadastro do cliente
#
#     nome: eddd,
#     e_mail: ssd,
#     senha: 23334
#
#
#
# 0
# 1
# ['Vestido', 'Tênis']
# [50.0, 100.0]
# Valor a pagar: R$150.0
# 1
# Para pagamento de cartão de crédito, você pode parcela em 12x sem juros
