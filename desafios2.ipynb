# %% [markdown]
# - ***Desafio 2:  Condicionais***
#
# ***Sistema de Reservas de Hotel:***
#
# ***Você foi contratado(a) para desenvolver uma parte do sistema de um hotel. O objetivo é criar um sistema que gerencie reservas de quartos e o pagamento das diárias***.
#
# - *Cadastro de Cliente:*
#
# *O sistema deve permitir que o usuário "cadastre" o nome e a idade de até 3 clientes.*
#
# - *Reservas de Quartos:*
#
# ***O sistema deve oferecer 3 tipos de quartos:***
#
# ***"Simples", "Duplo" e "Luxo".***
#
# ***Cada cliente deve escolher um quarto para sua estadia.
# O preço da diária varia conforme o tipo de quarto:
# Simples: R$ 100,00 por dia.
# Duplo: R$ 150,00 por dia.
# Luxo: R$ 250,00 por dia.***
#
# - ***Cálculo da Estadia:***
#
# ***O usuário deve informar quantos dias cada cliente ficará no hotel.
# O sistema deve calcular o valor total da estadia para cada cliente, considerando o tipo de quarto e a quantidade de dias.***
#
# Exemplo:
#
#  ***valor_cliente3 = preco_duplo * cliente3_dias***
#
# *Pagamento:*
#
# *O sistema deve exibir o valor total a ser pago por cada cliente após a aplicação do desconto.*
#
# *Regras Adicionais:
# Utilize apenas variáveis, condicionais (if, elif, else) e listas para resolver o desafio.*
#
# ***O sistema não deve usar loops (for, while) nem funções.**
# O código deve considerar todos os casos possíveis de escolha dos clientes.*

# %%
cadastro_cliente = [] # --> Exemplo depois que o usuario digitar o nome do cliente[" Roberta"; "andreza", "Rosa"]
tipos_quartos = ["Simples", "Duplo", "Luxo"]
preco_quartos = [100, 150, 250 ]
dias_estadia = []
carrinho = []
formas_de_pagamento = ["Pix", "Cartão de crédito", "Cartão de debito "]

print("Sejam Bem-vindo ao Hotel Raujo ")

nome_cliente1 = input("Digite o nome do primeiro cliente: ") # [0]
idade_cliente1 = int(input("Digite a idade do primeiro cliente: "))
cadastro_cliente.append({"nome": nome_cliente1, "idade_cliente": idade_cliente1})

nome_cliente2 = input("Digite o nome do segundo cliente: ")
idade_cliente2  = int(input("Digite a idade do segundo cliente: ")) # [1]
cadastro_cliente.append({"nome": nome_cliente2, "idade_cliente": 2})

nome_cliente3 = input("Digite o nome do terceiro cliente: ") # [2]
idade_cliente3 = int(input("Digite a idade do terceiro cliente: "))
cadastro_cliente.append({"nome": nome_cliente3, "idade_cliente": idade_cliente3})

print("Cadastros dos clientes")

print(f"nome:{cadastro_cliente[0]["nome"]}, idade:{cadastro_cliente[0]["idade_cliente"]}")
print(f"nome:{cadastro_cliente[1]["nome"]}, idade:{cadastro_cliente[1]["idade_cliente"]}")
print(f"nome:{cadastro_cliente[2]["nome"]}, idade:{cadastro_cliente[2]["idade_cliente"]}")

quarto1 = int(input(f"Digite o código do quarto: 0 - Simples, 1 - Duplo, 2 - Luxo"))
quarto2 = int(input(f"Digite o código do quarto: 0 - Simples, 1 - Duplo, 2 - Luxo"))
quarto3 = int(input(f"Digite o código do quarto: 0 - Simples, 1 - Duplo, 2 - Luxo"))

estadia1 = int(input("Quantos dias o primeiro cliente vai ficar: "))
dias_estadia.append(estadia1)
estadia2 = int(input("Quantos dias o segundo cliente vai ficar: "))
dias_estadia.append(estadia2)
estadia3 = int(input("Quantos dias o terceiro cliente vai ficar: "))
dias_estadia.append(estadia3)

carrinho = [tipos_quartos[0], tipos_quartos[1], tipos_quartos[2]]
valores = [preco_quartos[0], preco_quartos[1], preco_quartos[2]]

valor_total_cliente1 = preco_quartos[0] * dias_estadia[0]
valor_total_cliente2 = preco_quartos[1] * dias_estadia[1]
valor_total_cliente3 = preco_quartos[2] * dias_estadia[2]

desconto_cliente1 = (valor_total_cliente1 * 0.10) 
desconto_final_cliente1 = valor_total_cliente1 - desconto_cliente1
print(desconto_cliente1)
print(desconto_final_cliente1)

desconto_cliente2 = (valor_total_cliente2 * 0.10) 
desconto_final_cliente2 = valor_total_cliente2 - desconto_cliente2
print(desconto_cliente2)
print(desconto_final_cliente2)

desconto_cliente3 = (valor_total_cliente3 * 0.10) 
desconto_final_cliente3 = valor_total_cliente3 - desconto_cliente3
print(desconto_cliente3)
print(desconto_final_cliente3)



forma_pagamento = int(input("Digite o código do pagamento: 0 - Pix, 1 - Cartão de crédito, 2 - Cartão de débito "))
print(forma_pagamento)

if forma_pagamento == 0:
    print("No pix teria um desconto de 10% ")
elif forma_pagamento == 1:
    print("No cartão de crédito teria um desconto de 10% ")
else:
    print(" No cartão de débito teria um desconto de 10% ")

print(f"""

{cadastro_cliente[0] ["nome"]}, {tipos_quartos [0]} no perio valor total é de R$ {desconto_final_cliente1} já com desconto de 10%
{cadastro_cliente[1] ["nome"]}, {tipos_quartos [1]} no perio valor total é de R$ {desconto_final_cliente1} já com desconto de 10%
{cadastro_cliente[2] ["nome"]}, {tipos_quartos [2]} no perio valor total é de R$ {desconto_final_cliente1} já com desconto de 10%


""")
# Out:
# Sejam Bem-vindo ao Hotel Raujo
# Cadastros dos clientes
# nome:kh, idade:15
# nome:nu, idade:2
# nome:mimir, idade:26
# 100.0
# 900.0
# 150.0
# 1350.0
# 250.0
# 2250.0
# 1
# No cartão de crédito teria um desconto de 10%
#
#
# kh, Simples no perio valor total é de R$ 900.0 já com desconto de 10%
# nu, Duplo no perio valor total é de R$ 900.0 já com desconto de 10%
# mimir, Luxo no perio valor total é de R$ 900.0 já com desconto de 10%
